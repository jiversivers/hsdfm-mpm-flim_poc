# %%
import pandas as pd
df = pd.read_csv("phasor_validation_sweep_stats.csv")

# %%
df
# Out:
#         Unnamed: 0       true_t1       true_t2  center_alpha  spread_alpha  \
# 0                0  1.000000e-10  1.500000e-09          0.00          0.00
# 1                1  1.000000e-10  1.500000e-09          0.00          0.00
# 2                2  1.000000e-10  1.500000e-09          0.00          0.05
# 3                3  1.000000e-10  1.500000e-09          0.00          0.05
# 4                4  1.000000e-10  1.500000e-09          0.00          0.10
# ...            ...           ...           ...           ...           ...
# 187195      187195  9.500000e-10  7.750000e-09          0.95          0.35
# 187196      187196  9.500000e-10  7.750000e-09          0.95          0.40
# 187197      187197  9.500000e-10  7.750000e-09          0.95          0.40
# 187198      187198  9.500000e-10  7.750000e-09          0.95          0.45
# 187199      187199  9.500000e-10  7.750000e-09          0.95          0.45
#
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df["true_t2"], df["t1_bias"])
plt.scatter(df["true_t2"], df["t1_rmse"])
